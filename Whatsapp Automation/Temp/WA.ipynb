# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager

from time import sleep

driver = webdriver.Chrome(ChromeDriverManager().install())

# driver = webdriver.Chrome()
driver.get('https://web.whatsapp.com')
input("Scan the QR")
# Out:
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 103.0.5060
# [WDM] - Get LATEST chromedriver version for 103.0.5060 google-chrome
# [WDM] - Driver [C:\Users\Asif.Kasi\.wdm\drivers\chromedriver\win32\103.0.5060.53\chromedriver.exe] found in cache
# C:\Users\ASIF~1.KAS\AppData\Local\Temp/ipykernel_5728/3559978084.py:6: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install())
# ''

# %%
# driver.get('https://web.whatsapp.com')
# driver.get('https://web.whatsapp.com/send?phone=+923002067741')

# %%
# name = input('Enter the name of user or group : ')
# var = 
lis_name = ["+92 300 2067741","+92 307 2402182"]
# filepath = "D:\\AoE-Data-\\yOUTUBE LINKS.txt"
filepath = "\\cncd-dc1\Asif Kasi Lab\ASCII Characters.pdf"


# name = "+92 307 2402182" 
# filepath = input('Enter your filepath (images/video): ')
# input('Enter anything after scanning QR code')
# filepath
# driver.find_element_by_xpath("xpath here")
# user = driver.find_element_by_xpath('//span[@title = "{}"]'.format(name))

for i in range(len(lis_name)):

    name = lis_name[i] 
    driver.get('https://web.whatsapp.com/send?phone='+name)
    driver.minimize_window()
    
    print(name)



    # user = driver.find_element("xpath",'//span[@title = "{}"]'.format(name))
    # user.click()

    attachment_box = driver.find_element("xpath",'//div[@title = "Attach"]')
    attachment_box.click()



    image_box = driver.find_element("xpath",
        '//input[@accept="image/*,video/mp4,video/3gpp,video/quicktime"]')
    image_box.send_keys(filepath)



    sleep(3)

    send_button = driver.find_element("xpath",'//span[@data-icon="send"]')

    send_button.click()
    print(name+" *********88")
# Out:
# +92 300 2067741
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# C:\Users\ASIF~1.KAS\AppData\Local\Temp/ipykernel_6768/2678492226.py in <module>
#      27     # user.click()
#      28
# ---> 29     attachment_box = driver.find_element("xpath",'//div[@title = "Attach"]')
#      30     attachment_box.click()
#      31
#
# c:\Users\Asif.Kasi\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     855             value = '[name="%s"]' % value
#     856
# --> 857         return self.execute(Command.FIND_ELEMENT, {
#     858             'using': by,
#     859             'value': value})['value']
#
# c:\Users\Asif.Kasi\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     433         response = self.command_executor.execute(driver_command, params)
#     434         if response:
# --> 435             self.error_handler.check_response(response)
#     436             response['value'] = self._unwrap_value(
#     437                 response.get('value', None))
#
# c:\Users\Asif.Kasi\Anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     245                 alert_text = value['alert'].get('text')
#     246             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247         raise exception_class(message, screen, stacktrace)
#     248
#     249     def _value_or_default(self, obj: Mapping[_KT, _VT], key: _KT, default: _VT) -> _VT:
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//div[@title = "Attach"]"}
#   (Session info: chrome=103.0.5060.66)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x00B86463+2188387]
# 	Ordinal0 [0x00B1E461+1762401]
# 	Ordinal0 [0x00A33D78+802168]
# 	Ordinal0 [0x00A61880+989312]
# 	Ordinal0 [0x00A61B1B+989979]
# 	Ordinal0 [0x00A8E912+1173778]
# 	Ordinal0 [0x00A7C824+1099812]
# 	Ordinal0 [0x00A8CC22+1166370]
# 	Ordinal0 [0x00A7C5F6+1099254]
# 	Ordinal0 [0x00A56BE0+945120]
# 	Ordinal0 [0x00A57AD6+948950]
# 	GetHandleVerifier [0x00E271F2+2712546]
# 	GetHandleVerifier [0x00E1886D+2652765]
# 	GetHandleVerifier [0x00C1002A+520730]
# 	GetHandleVerifier [0x00C0EE06+516086]
# 	Ordinal0 [0x00B2468B+1787531]
# 	Ordinal0 [0x00B28E88+1805960]
# 	Ordinal0 [0x00B28F75+1806197]
# 	Ordinal0 [0x00B31DF1+1842673]
# 	BaseThreadInitThunk [0x75856739+25]
# 	RtlGetFullPathName_UEx [0x774F8FEF+1215]
# 	RtlGetFullPathName_UEx [0x774F8FBD+1165]

# %%
# driver.minimize_window()
# input("Scan QR Code and Enter any key")
# type_it = driver.find_element_by_class_name('_13NKt')

msgHI = driver.find_element("xpath",'//div[@title = "Type a message"]')
time.sleep(20)
msgHI.click()


send_button = driver.find_element("xpath",'//span[@data-icon="send"]')

send_button.click()
# Out:
# ---------------------------------------------------------------------------
# UnexpectedAlertPresentException           Traceback (most recent call last)
# C:\Users\ASIF~1.KAS\AppData\Local\Temp/ipykernel_784/2954482812.py in <module>
#       4 # type_it = driver.find_element_by_class_name('_13NKt')
#       5
# ----> 6 msgHI = driver.find_element("xpath",'//div[@title = "Type a message"]')
#       7 time.sleep(20)
#       8 msgHI.click()
#
# c:\Users\Asif.Kasi\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     855             value = '[name="%s"]' % value
#     856
# --> 857         return self.execute(Command.FIND_ELEMENT, {
#     858             'using': by,
#     859             'value': value})['value']
#
# c:\Users\Asif.Kasi\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     433         response = self.command_executor.execute(driver_command, params)
#     434         if response:
# --> 435             self.error_handler.check_response(response)
#     436             response['value'] = self._unwrap_value(
#     437                 response.get('value', None))
#
# c:\Users\Asif.Kasi\Anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     244             elif 'alert' in value:
#     245                 alert_text = value['alert'].get('text')
# --> 246             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
#     247         raise exception_class(message, screen, stacktrace)
#     248
#
# UnexpectedAlertPresentException: Alert Text: {Alert text :
# Message: unexpected alert open: {Alert text : }
#   (Session info: chrome=103.0.5060.66)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x00B86463+2188387]
# 	Ordinal0 [0x00B1E461+1762401]
# 	Ordinal0 [0x00A33D78+802168]
# 	Ordinal0 [0x00A8CA92+1165970]
# 	Ordinal0 [0x00A7C5F6+1099254]
# 	Ordinal0 [0x00A56BE0+945120]
# 	Ordinal0 [0x00A57AD6+948950]
# 	GetHandleVerifier [0x00E271F2+2712546]
# 	GetHandleVerifier [0x00E1886D+2652765]
# 	GetHandleVerifier [0x00C1002A+520730]
# 	GetHandleVerifier [0x00C0EE06+516086]
# 	Ordinal0 [0x00B2468B+1787531]
# 	Ordinal0 [0x00B28E88+1805960]
# 	Ordinal0 [0x00B28F75+1806197]
# 	Ordinal0 [0x00B31DF1+1842673]
# 	BaseThreadInitThunk [0x75856739+25]
# 	RtlGetFullPathName_UEx [0x774F8FEF+1215]
# 	RtlGetFullPathName_UEx [0x774F8FBD+1165]

# %%
type_it = driver.find_element('_13NKt')
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentException                  Traceback (most recent call last)
# C:\Users\ASIF~1.KAS\AppData\Local\Temp/ipykernel_784/467988724.py in <module>
# ----> 1 type_it = driver.find_element('_13NKt')
#
# c:\Users\Asif.Kasi\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     855             value = '[name="%s"]' % value
#     856
# --> 857         return self.execute(Command.FIND_ELEMENT, {
#     858             'using': by,
#     859             'value': value})['value']
#
# c:\Users\Asif.Kasi\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     433         response = self.command_executor.execute(driver_command, params)
#     434         if response:
# --> 435             self.error_handler.check_response(response)
#     436             response['value'] = self._unwrap_value(
#     437                 response.get('value', None))
#
# c:\Users\Asif.Kasi\Anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     245                 alert_text = value['alert'].get('text')
#     246             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247         raise exception_class(message, screen, stacktrace)
#     248
#     249     def _value_or_default(self, obj: Mapping[_KT, _VT], key: _KT, default: _VT) -> _VT:
#
# InvalidArgumentException: Message: invalid argument: invalid locator
#   (Session info: chrome=103.0.5060.66)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x00B86463+2188387]
# 	Ordinal0 [0x00B1E461+1762401]
# 	Ordinal0 [0x00A33D78+802168]
# 	Ordinal0 [0x00A61A11+989713]
# 	Ordinal0 [0x00A61B1B+989979]
# 	Ordinal0 [0x00A8E912+1173778]
# 	Ordinal0 [0x00A7C824+1099812]
# 	Ordinal0 [0x00A8CC22+1166370]
# 	Ordinal0 [0x00A7C5F6+1099254]
# 	Ordinal0 [0x00A56BE0+945120]
# 	Ordinal0 [0x00A57AD6+948950]
# 	GetHandleVerifier [0x00E271F2+2712546]
# 	GetHandleVerifier [0x00E1886D+2652765]
# 	GetHandleVerifier [0x00C1002A+520730]
# 	GetHandleVerifier [0x00C0EE06+516086]
# 	Ordinal0 [0x00B2468B+1787531]
# 	Ordinal0 [0x00B28E88+1805960]
# 	Ordinal0 [0x00B28F75+1806197]
# 	Ordinal0 [0x00B31DF1+1842673]
# 	BaseThreadInitThunk [0x75856739+25]
# 	RtlGetFullPathName_UEx [0x774F8FEF+1215]
# 	RtlGetFullPathName_UEx [0x774F8FBD+1165]

# %%
msgHI
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\ASIF~1.KAS\AppData\Local\Temp/ipykernel_784/1162255217.py in <module>
# ----> 1 msgHI
#
# NameError: name 'msgHI' is not defined

# %%
driver.find_element("xpath",'//div[@role="textbox"]')
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="f395b92e131d36ea3145c0e5bf694d39", element="0747e2ff-fed3-4450-aef2-1ea6578e899e")>

# %%
type_it[1].send_keys(message_content + Keys.ENTER)

# %%
# name = input('Enter the name of user or group : ')
# var = 
lis_name = ["+92 300 2067741","+92 307 2402182"]
# filepath = "D:\\AoE-Data-\\yOUTUBE LINKS.txt"
filepath = "\\cncd-dc1\Asif Kasi Lab\ASCII Characters.pdf"
driver.get('https://web.whatsapp.com')


# name = "+92 307 2402182" 
# filepath = input('Enter your filepath (images/video): ')
# input('Enter anything after scanning QR code')
# filepath
# driver.find_element_by_xpath("xpath here")
# user = driver.find_element_by_xpath('//span[@title = "{}"]'.format(name))

for i in range(len(lis_name)):

    name = lis_name[i] 
    driver.get('https://web.whatsapp.com/send?phone='+name)
    driver.minimize_window()
    
    print(name)



    user = driver.find_element("xpath",'//span[@title = "{}"]'.format(name))
    user.click()

    attachment_box = driver.find_element("xpath",'//div[@title = "Attach"]')
    attachment_box.click()



    image_box = driver.find_element("xpath",
        '//input[@accept="image/*,video/mp4,video/3gpp,video/quicktime"]')
    image_box.send_keys(filepath)



    sleep(3)

    send_button = driver.find_element("xpath",'//span[@data-icon="send"]')

    send_button.click()
    print(name+" *********88")
