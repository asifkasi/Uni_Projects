# %%
from selenium import webdriver

from webdriver_manager.chrome import ChromeDriverManager

from time import sleep

driver = webdriver.Chrome(ChromeDriverManager().install())
driver.get('https://web.whatsapp.com')

input("Scan the QR")
# Out:
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 103.0.5060
# [WDM] - Get LATEST chromedriver version for 103.0.5060 google-chrome
# [WDM] - Driver [C:\Users\Asif_\.wdm\drivers\chromedriver\win32\103.0.5060.53\chromedriver.exe] found in cache
# C:\Users\Asif_\AppData\Local\Temp/ipykernel_7248/4162987815.py:5: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install())
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7248/4162987815.py in <module>
#       4
#       5 driver = webdriver.Chrome(ChromeDriverManager().install())
# ----> 6 driver.get('https://web.whatsapp.com')
#       7
#       8 input("Scan the QR")
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in get(self, url)
# ...

# %%
import pandas as pd
pd.options.display.float_format = '{:,.0f}'.format

# %%
df = pd.read_excel(r"C:\Users\Asif_\Downloads\UNI-k-projects\Whatsapp Automation\contacts.xlsx")
# df = df.astype(str)

df
# Out:
#     study_id    Name           Contact   File Name
# 0          1    Asif     3,002,067,741   1 (1).pdf
# 1          2  waseem     3,072,402,180   1 (2).pdf
# 2          3    saad     3,113,547,354   1 (3).pdf
# 3          4   Wrong               300   1 (4).pdf
# 4          5  wrong2    30,020,677,410   1 (5).pdf
# 5          6  wrong3               NaN   1 (6).pdf
# 6          7    Asif   923,002,067,741   1 (7).pdf
# 7          8  waseem   923,072,402,180   1 (8).pdf
# 8          9    saad   923,113,547,354   1 (9).pdf
# 9         10   Wrong            92,300  1 (10).pdf
# 10        11  wrong2 9,230,020,677,410  1 (11).pdf
# 11        12  wrong3                92  1 (12).pdf
# 12        13     NaN     3,002,067,741  1 (10).pdf
# 13       NaN     NaN     3,002,067,741  1 (10).pdf

# %%
df["Contact"][10]
# Out:
# 9230020677410.0

# %%
type(df["Contact"][10])
# Out:
# numpy.float64

# %%
# url ="https://web.whatsapp.com/send?phone=+91xxxxxxxxxx"
driver.get('https://web.whatsapp.com/send?phone=+923113547354')
time.sleep(5)



msgHI = driver.find_element("xpath",'//div[@title = "Type a message"]')




msgHI.send_keys("HI h")

send_button = driver.find_element("xpath",'//span[@data-icon="send"]')
send_button.click()
