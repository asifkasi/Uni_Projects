# %%
# pip install selenium
# pip install pywhatkit

# pip install pywhatkit

# %%
import pywhatkit


from datetime import datetime, timedelta
# now = datetime.now()
# print(now)
# #         now_plus_2 = now + timedelta(minutes = 1)
# now_plus_2 = now + timedelta(seconds=30)
# print(now_plus_2)

# importing the module

# using Exception Handling to avoi
# unprecedented errors
lis_name = ["+92 300 2067741","+92 307 2402182","+92 300 206774","+92 300 2067740"]
lis_notsend = []

for i in range(len(lis_name)):

    try:

    # sending message to receiver
    # using pywhatkit
        name = lis_name[i]
        now = datetime.now()
        print(now)
        
        now_plus_2 = now + timedelta(minutes = 1)
#         now_plus_2 = now + timedelta(seconds = 45)
        print(now_plus_2)
        
        # print now.year, now.month, now.day, now.hour, now.minute, now.second


        pywhatkit.sendwhatmsg(name,
                                "Hello from GeeksforGeeks",
                                now_plus_2.hour, now_plus_2.minute,tab_close=True,close_time = 3)










    #     print("Successfully Sent!")

    except:

        # handling exception
        # and printing error message
        print("An Unexpected Error!")
# Out:
# 2022-07-01 01:47:33.923205
# 2022-07-01 01:48:33.923205
# In 12 Seconds WhatsApp will open and after 15 Seconds Message will be Delivered!
# 2022-07-01 01:48:04.667853
# 2022-07-01 01:49:04.667853
# In 41 Seconds WhatsApp will open and after 15 Seconds Message will be Delivered!
# 2022-07-01 01:49:04.177070
# 2022-07-01 01:50:04.177070
# In 41 Seconds WhatsApp will open and after 15 Seconds Message will be Delivered!
# 2022-07-01 01:50:03.672304
# 2022-07-01 01:51:03.672304
# In 42 Seconds WhatsApp will open and after 15 Seconds Message will be Delivered!

# %%
https://www.youtube.com/watch?v=pQeFxdT3FGY&list=PLi0EGg6K7IY18yqY6Li67Bqnznj8VFH8a&index=5

# %%
import time
import pywhatkit

# %%
var = "+923002067741"
# var = "+923072402182"
# 
min = input("min")
min = int(min)
print(min)
start = time.process_time()

# your code here    
pywhatkit.sendwhatmsg(var,"Hi how r u",1,min,15,True,3)
print(time.process_time() - start)
# Out:
# min25
# 25
# In 29 Seconds WhatsApp will open and after 15 Seconds Message will be Delivered!
# 0.125

# %%
var = "+923002067740"
# var = "+923072402182"
# 
min = input("min")
min = int(min)
print(min)

start = time.process_time()
# your code here    
pywhatkit.sendwhatmsg(var,"Hi how r u",1,min,15,True,3)

# your code here    
# pywhatkit.sendwhatmsg(var,"Hi how r u",1,23,15,True,3)
print(time.process_time() - start)
# Out:
# min26
# 26
# In 36 Seconds WhatsApp will open and after 15 Seconds Message will be Delivered!
# 0.0

# %% [markdown]
# # Note
#
# number should not be saved
#
# number should not be in archived
#
# number format must be +92 xxx xxxxxx

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager

from time import sleep

# %%
driver = webdriver.Chrome(ChromeDriverManager().install())

# driver = webdriver.Chrome()
# Out:
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 103.0.5060
# [WDM] - Get LATEST chromedriver version for 103.0.5060 google-chrome
# [WDM] - There is no [win32] chromedriver for browser 103.0.5060 in cache
# [WDM] - About to download new driver from https://chromedriver.storage.googleapis.com/103.0.5060.53/chromedriver_win32.zip
# [WDM] - Driver has been saved in cache [C:\Users\Asif_\.wdm\drivers\chromedriver\win32\103.0.5060.53]
# C:\Users\Asif_\AppData\Local\Temp/ipykernel_9064/1453201617.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install())

# %%
driver.get('https://web.whatsapp.com/')

# %%
# name = input('Enter the name of user or group : ')
# var = 
lis_name = ["+92 300 2067741","+92 307 2402182"]
filepath = "D:\\AoE-Data-\\yOUTUBE LINKS.txt"
# name = "+92 307 2402182" 
# filepath = input('Enter your filepath (images/video): ')
# input('Enter anything after scanning QR code')
# filepath
# driver.find_element_by_xpath("xpath here")
# user = driver.find_element_by_xpath('//span[@title = "{}"]'.format(name))

for i in range(len(lis_name)):
    name = lis_name[i] 
    print(name)
    user = driver.find_element("xpath",'//span[@title = "{}"]'.format(name))
    user.click()

    attachment_box = driver.find_element("xpath",'//div[@title = "Attach"]')
    attachment_box.click()



    image_box = driver.find_element("xpath",
        '//input[@accept="image/*,video/mp4,video/3gpp,video/quicktime"]')
    image_box.send_keys(filepath)



    sleep(3)

    send_button = driver.find_element("xpath",'//span[@data-icon="send"]')

    send_button.click()
    print(name+" *********88")
# Out:
# +92 300 2067741
# +92 300 2067741 *********88
# +92 307 2402182
# +92 307 2402182 *********88
