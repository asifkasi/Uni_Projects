# %%
# pip install selenium
# pip install pywhatkit

# %%
# pip install pywhatkit
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.

# %%
# # var = "+92 307 2402182"
# var = "+923072402182"



# import pywhatkit
# pywhatkit.sendwhatmsg(var,"Hi how r u",23,8)

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager

from time import sleep

# %%
driver = webdriver.Chrome(ChromeDriverManager().install())

# driver = webdriver.Chrome()
# Out:
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 102.0.5005
# [WDM] - Get LATEST chromedriver version for 102.0.5005 google-chrome
# [WDM] - Driver [C:\Users\Asif_\.wdm\drivers\chromedriver\win32\102.0.5005.61\chromedriver.exe] found in cache
# C:\Users\Asif_\AppData\Local\Temp/ipykernel_1344/1453201617.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install())

# %%
driver.get('https://web.whatsapp.com/')

# %%
# name = input('Enter the name of user or group : ')
# var = 

lis_name = ["92 300 2067741","+92 307 2402182"]


# name = "+92 307 2402182" 



# filepath = input('Enter your filepath (images/video): ')
filepath = "D:\\AoE-Data-\\yOUTUBE LINKS.txt"
input('Enter anything after scanning QR code')


filepath

# driver.find_element_by_xpath("xpath here")

# user = driver.find_element_by_xpath('//span[@title = "{}"]'.format(name))
user = driver.find_element("xpath",'//span[@title = "{}"]'.format(name))


user.click()

attachment_box = driver.find_element("xpath",'//div[@title = "Attach"]')
attachment_box.click()



image_box = driver.find_element("xpath",
    '//input[@accept="image/*,video/mp4,video/3gpp,video/quicktime"]')
image_box.send_keys(filepath)



sleep(3)

send_button = driver.find_element("xpath",'//span[@data-icon="send"]')

send_button.click()
# Out:
# Enter anything after scanning QR code
